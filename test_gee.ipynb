# %%
# Run this cell to authenticate with GEE
# When prompted :
#   select `Cloud Project: imars-simm-belize`
#   "Generate Token"
#   "Continue" past safety warning
#   Check boxes & "Continue"
#   Paste the code into the box below & press enter
ee.Authenticate(auth_mode="notebook")
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/cloud-platform%20https%3A//www.googleapis.com/auth/drive%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=ycMEfrpMnqy3t_MKkmm2s5tgbwop8VcpadnVdxiiM-I&tc=dSs2OrdyRKzkBAM273aY9f9fccdSvvpQ_ExiEDmDKcQ&cc=lZuGlm3lOU7xRTNpFJ_vfL4I8IfENHpIUcpp4fHNrs0>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/cloud-platform%20https%3A//www.googleapis.com/auth/drive%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=ycMEfrpMnqy3t_MKkmm2s5tgbwop8VcpadnVdxiiM-I&tc=dSs2OrdyRKzkBAM273aY9f9fccdSvvpQ_ExiEDmDKcQ&cc=lZuGlm3lOU7xRTNpFJ_vfL4I8IfENHpIUcpp4fHNrs0</a></p>
# ...

# %%
# Run this cell to test GEE.
# An Image ID should be printed.
import ee

ee.Initialize(project="imars-simm-belize")
img = ee.ImageCollection("COPERNICUS/S2_SR_HARMONIZED").first()

print("Image ID:")
print(img.get("PRODUCT_ID").getInfo())
# Out:
# Image ID:
# S2A_MSIL2A_20150704T101006_N0500_R022_T33VXK_20231010T083126
